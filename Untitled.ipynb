# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.concat([pd.read_csv(f'./data/{file}') for file in os.listdir('./data/')], ignore_index=True)

# %%
df.head()
# Out:
#    batch_date        test_name       swab_type covid19_test_results  age  \
# 0  2020-06-16  SARS-CoV-2, NAA           Nasal             Negative   15
# 1  2020-06-16   SARS COV2 NAAT  Nasopharyngeal             Negative   20
# 2  2020-06-16  SARS-CoV-2, NAA           Nasal             Negative   14
# 3  2020-06-16  SARS-CoV-2, NAA  Nasopharyngeal             Negative   32
# 4  2020-06-16  SARS-CoV-2, NAA           Nasal             Negative   29
#
#   high_risk_exposure_occupation high_risk_interactions  diabetes    chd  \
# 0                         False                  False     False  False
# 1                         False                  False     False  False
# 2                         False                    NaN     False  False
# 3                         False                  False     False  False
# 4                         False                   True     False  False
#
#      htn  ...  loss_of_smell  loss_of_taste  runny_nose  muscle_sore  \
# ...

# %%
df.groupby('batch_date').count()
# Out:
#             test_name  swab_type  covid19_test_results   age  \
# batch_date
# 2020-04-07        735        735                   735   735
# 2020-04-14        263        263                   263   263
# 2020-04-21       1106       1106                  1106  1106
# 2020-04-28       1167       1167                  1167  1167
# 2020-05-05       1601       1601                  1601  1601
# 2020-05-12        593        593                   593   593
# 2020-05-19        934        934                   934   934
# 2020-05-26        750        750                   750   750
# 2020-06-02        989        989                   989   989
# 2020-06-09       1585       1585                  1585  1585
# 2020-06-16       1446       1446                  1446  1446
# 2020-06-23       2425       2425                  2425  2425
# 2020-06-30       2684       2684                  2684  2684
# 2020-07-07       2612       2612                  2612  2612
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93995 entries, 0 to 93994
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   batch_date                     93995 non-null  object
#  1   test_name                      93995 non-null  object
#  2   swab_type                      93995 non-null  object
#  3   covid19_test_results           93995 non-null  object
#  4   age                            93995 non-null  int64
#  5   high_risk_exposure_occupation  93826 non-null  object
#  6   high_risk_interactions         69168 non-null  object
#  7   diabetes                       93995 non-null  bool
#  8   chd                            93995 non-null  bool
#  9   htn                            93995 non-null  bool
#  10  cancer                         93995 non-null  bool
#  11  asthma                         93995 non-null  bool
# ...

# %%
df[df['cxr_link'].notnull()][['cxr_link']].count()
# Out:
# cxr_link    689
# dtype: int64

# %%
xray_features = [f for f in df.columns if 'cxr_' in f]

xray_links = df[df['cxr_link'].notnull()][xray_features]

# %%
xray_links
# Out:
#                                             cxr_findings  \
# 96     The cardiac silhouette is normal.\nThere is no...
# 130    The cardiac silhouette is normal.\nThere is no...
# 221    The cardiac silhouette is normal.\nThere is no...
# 314    The cardiac silhouette is normal.\nThere is no...
# 323    The cardiac silhouette is normal.\nThere is no...
# ...                                                  ...
# 93118  The cardiac silhouette is normal.\nThere is no...
# 93345  The cardiac silhouette is normal.\nThere is no...
# 93370  The cardiac silhouette is normal.\nThere is no...
# 93403  The cardiac silhouette is normal.\nThere is no...
# 93974  The cardiac silhouette is normal.\nThere is no...
#
#                                           cxr_impression    cxr_label  \
# 96     No significant abnormality.\n\nPlease note tha...     Negative
# 130    Subtle multifocal pericentimeter pulmonary opa...  Significant
# ...

# %%
xray_links['cxr_label'].value_counts(normalize=True)
# Out:
# Negative       0.872279
# Significant    0.120464
# Critical       0.007257
# Name: cxr_label, dtype: float64

# %%
df.shape
# Out:
# (93995, 46)

# %%
df['er_referral'].value_counts()
# Out:
# False    11169
# Name: er_referral, dtype: int64

# %%
xray_links.to_csv('./xray_links.csv')
